# %% [markdown]
# **DATA CLEANING**

# %% [markdown]
# **LOADING DATA**

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\User\Desktop\Data Analyst projects Projects others\NYC+Accidents+2020.csv\NYC Accidents 2020.csv")
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  2020-08-29   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1  2020-08-29   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2  2020-08-29   18:20:00       NaN       NaN  40.81650 -73.946556
# 3  2020-08-29   00:00:00     BRONX   10459.0  40.82472 -73.892960
# 4  2020-08-29   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# ...

# %%
#Removing Unwanted Vehicle code 1,3,4,5
#df.head()
#df.drop(columns =["VEHICLE TYPE CODE 1","VEHICLE TYPE CODE 3" , "VEHICLE TYPE CODE 4", "VEHICLE TYPE CODE 5"], inplace = True)
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  2020-08-29   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1  2020-08-29   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2  2020-08-29   18:20:00       NaN       NaN  40.81650 -73.946556
# 3  2020-08-29   00:00:00     BRONX   10459.0  40.82472 -73.892960
# 4  2020-08-29   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  NUMBER OF CYCLIST KILLED  \
# 0                  NaN  ...                         0
# 1                  NaN  ...                         0
# ...

# %% [markdown]
# **Removing vehocle contributing Factor 2,3,4,5**

# %%
#Removing vehocle contributing Factor 2,3,4,5
#df.drop(columns = ["CONTRIBUTING FACTOR VEHICLE 2","CONTRIBUTING FACTOR VEHICLE 3","CONTRIBUTING FACTOR VEHICLE 4","CONTRIBUTING FACTOR VEHICLE 5"], inplace = True)
df
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      2020-08-29   15:40:00      BRONX   10466.0  40.892100 -73.833760
# 1      2020-08-29   21:00:00   BROOKLYN   11221.0  40.690500 -73.919914
# 2      2020-08-29   18:20:00        NaN       NaN  40.816500 -73.946556
# 3      2020-08-29   00:00:00      BRONX   10459.0  40.824720 -73.892960
# 4      2020-08-29   17:10:00   BROOKLYN   11203.0  40.649890 -73.933890
# ...           ...        ...        ...       ...        ...        ...
# 74876  2020-01-01   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877  2020-01-01   08:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878  2020-01-01   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879  2020-01-01   01:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880  2020-01-01   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION   ON STREET NAME CROSS STREET NAME  \
# ...

# %% [markdown]
# **splitting  the VEHICLE TYPE CODE 2 column into Vehicle Type,Vehicle Category**

# %%
df[["Vehicle Type","Vehicle Category"]]=df["VEHICLE TYPE CODE 2"].str.split("/", n=1, expand=True)
df
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      2020-08-29   15:40:00      BRONX   10466.0  40.892100 -73.833760
# 1      2020-08-29   21:00:00   BROOKLYN   11221.0  40.690500 -73.919914
# 2      2020-08-29   18:20:00        NaN       NaN  40.816500 -73.946556
# 3      2020-08-29   00:00:00      BRONX   10459.0  40.824720 -73.892960
# 4      2020-08-29   17:10:00   BROOKLYN   11203.0  40.649890 -73.933890
# ...           ...        ...        ...       ...        ...        ...
# 74876  2020-01-01   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877  2020-01-01   08:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878  2020-01-01   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879  2020-01-01   01:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880  2020-01-01   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION   ON STREET NAME CROSS STREET NAME  \
# ...

# %% [markdown]
# **Filling Null values with Unknown**

# %%
cols = ["VEHICLE TYPE CODE 2", "Vehicle Type", "Vehicle Category"]
df[cols]=df[cols].fillna("Unknown")
df.drop(columns="VEHICLE TYPE CODE 2",inplace = True)
df.drop(columns = ["CROSS STREET NAME","OFF STREET NAME"], inplace =  True)
df
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      2020-08-29   15:40:00      BRONX   10466.0  40.892100 -73.833760
# 1      2020-08-29   21:00:00   BROOKLYN   11221.0  40.690500 -73.919914
# 2      2020-08-29   18:20:00        NaN       NaN  40.816500 -73.946556
# 3      2020-08-29   00:00:00      BRONX   10459.0  40.824720 -73.892960
# 4      2020-08-29   17:10:00   BROOKLYN   11203.0  40.649890 -73.933890
# ...           ...        ...        ...       ...        ...        ...
# 74876  2020-01-01   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877  2020-01-01   08:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878  2020-01-01   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879  2020-01-01   01:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880  2020-01-01   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION   ON STREET NAME  \
# ...

# %%
df.rename({
    "ON STREET NAME": "Street Name",
    "NUMBER OF PERSONS INJURED": "Persons Injured",
    "NUMBER OF PERSONS KILLED": "Persons Killed",
    "NUMBER OF PEDESTRIANS INJURED": "Pedestrians Injured",
    "NUMBER OF PEDESTRIANS KILLED": "Pedestrians Killed",
    "NUMBER OF CYCLIST INJURED": "Cyclist Injured",
    "NUMBER OF MOTORIST INJURED": "Motorist Injured",
    "NUMBER OF MOTORIST KILLED": "Motorist Killed",
    "NUMBER OF CYCLIST KILLED": "Cyclist Killed",
    "CONTRIBUTING FACTOR VEHICLE 1":"Factor",
    "COLLISION_ID": "Collision_Id",
    "CRASH DATE":"Crash Date",
    "CRASH TIME":"Crash Time",
    "BOROUGH":"Borough",
    "ZIP CODE":"Zip Code"
}, axis=1, inplace=True)
df
# Out:
#        Crash Date Crash Time    Borough  Zip Code   LATITUDE  LONGITUDE  \
# 0      2020-08-29   15:40:00      BRONX   10466.0  40.892100 -73.833760
# 1      2020-08-29   21:00:00   BROOKLYN   11221.0  40.690500 -73.919914
# 2      2020-08-29   18:20:00        NaN       NaN  40.816500 -73.946556
# 3      2020-08-29   00:00:00      BRONX   10459.0  40.824720 -73.892960
# 4      2020-08-29   17:10:00   BROOKLYN   11203.0  40.649890 -73.933890
# ...           ...        ...        ...       ...        ...        ...
# 74876  2020-01-01   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877  2020-01-01   08:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878  2020-01-01   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879  2020-01-01   01:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880  2020-01-01   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION      Street Name  Persons Injured  \
# ...

# %%
#df.drop(columns = ["Zip Code","LATITUDE","LONGITUDE","LOCATION","Street Name"],inplace = True)
#df.drop(columns = "Street Name",inplace = True)
df
# Out:
#        Crash Date Crash Time    Borough  Persons Injured  Persons Killed  \
# 0      2020-08-29   15:40:00      BRONX                0               0
# 1      2020-08-29   21:00:00   BROOKLYN                2               0
# 2      2020-08-29   18:20:00        NaN                1               0
# 3      2020-08-29   00:00:00      BRONX                0               0
# 4      2020-08-29   17:10:00   BROOKLYN                0               0
# ...           ...        ...        ...              ...             ...
# 74876  2020-01-01   15:13:00      BRONX                0               0
# 74877  2020-01-01   08:00:00   BROOKLYN                0               0
# 74878  2020-01-01   11:36:00      BRONX                0               0
# 74879  2020-01-01   01:45:00  MANHATTAN                0               0
# 74880  2020-01-01   18:00:00     QUEENS                2               0
#
#        Pedestrians Injured  Pedestrians Killed  Cyclist Injured  \
# ...

# %%
#df["Crash Date"] = pd.to_datetime(df["Crash Date"])
#df["Month Crash"] = df["Crash Date"].dt.strftime("%b")
#df["Day Crash"] = df["Crash Date"].dt.strftime("%a")
#df["Year"] = df["Crash Date"].dt.year
df
# Out:
#       Crash Date Crash Time    Borough  Persons Injured  Persons Killed  \
# 0     2020-08-29   15:40:00      BRONX                0               0
# 1     2020-08-29   21:00:00   BROOKLYN                2               0
# 2     2020-08-29   18:20:00        NaN                1               0
# 3     2020-08-29   00:00:00      BRONX                0               0
# 4     2020-08-29   17:10:00   BROOKLYN                0               0
# ...          ...        ...        ...              ...             ...
# 74876 2020-01-01   15:13:00      BRONX                0               0
# 74877 2020-01-01   08:00:00   BROOKLYN                0               0
# 74878 2020-01-01   11:36:00      BRONX                0               0
# 74879 2020-01-01   01:45:00  MANHATTAN                0               0
# 74880 2020-01-01   18:00:00     QUEENS                2               0
#
#        Pedestrians Injured  Pedestrians Killed  Cyclist Injured  \
# ...

# %%
#df["Crash Time"] = pd.to_datetime(df["Crash Time"]).dt.hour
df
# Out:
#       Crash Date  Crash Time    Borough  Persons Injured  Persons Killed  \
# 0     2020-08-29          15      BRONX                0               0
# 1     2020-08-29          21   BROOKLYN                2               0
# 2     2020-08-29          18        NaN                1               0
# 3     2020-08-29           0      BRONX                0               0
# 4     2020-08-29          17   BROOKLYN                0               0
# ...          ...         ...        ...              ...             ...
# 74876 2020-01-01          15      BRONX                0               0
# 74877 2020-01-01           8   BROOKLYN                0               0
# 74878 2020-01-01          11      BRONX                0               0
# 74879 2020-01-01           1  MANHATTAN                0               0
# 74880 2020-01-01          18     QUEENS                2               0
#
#        Pedestrians Injured  Pedestrians Killed  Cyclist Injured  \
# ...

# %%
#df["Borough"] = df["Borough"].fillna("Unknown")
#df[df.duplicated()]
#df.drop_duplicates(inplace = True)
#df.dropna()
df["Factor"].dropna(inplace = True)
df
# Out:
#       Crash Date  Crash Time    Borough  Persons Injured  Persons Killed  \
# 0     2020-08-29          15      BRONX                0               0
# 1     2020-08-29          21   BROOKLYN                2               0
# 2     2020-08-29          18    Unknown                1               0
# 3     2020-08-29           0      BRONX                0               0
# 4     2020-08-29          17   BROOKLYN                0               0
# ...          ...         ...        ...              ...             ...
# 74876 2020-01-01          15      BRONX                0               0
# 74877 2020-01-01           8   BROOKLYN                0               0
# 74878 2020-01-01          11      BRONX                0               0
# 74879 2020-01-01           1  MANHATTAN                0               0
# 74880 2020-01-01          18     QUEENS                2               0
#
#        Pedestrians Injured  Pedestrians Killed  Cyclist Injured  \
# ...

# %%
df.to_csv("Accidents_2.csv", index = False)
